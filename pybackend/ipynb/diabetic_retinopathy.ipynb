# %% [markdown]
# EYE

# %%
# !kaggle datasets download -d arbethi/diabetic-retinopathy-level-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/arbethi/diabetic-retinopathy-level-detection
# License(s): CC0-1.0
# ^C

# %%
# !ls
# Out:
# chest_xray		  indian_liver_patient.csv
# chest-xray-pneumonia.zip  indian-liver-patient-records.zip
# ham10000_images_part_1	  kaggle.json
# HAM10000_images_part_1	  liver_model.pkl
# ham10000_images_part_2	  liver_scaler.pkl
# HAM10000_images_part_2	  pneumonia_xray_model.h5
# HAM10000_metadata.csv	  sample_data
# hmnist_28_28_L.csv	  skin-cancer-mnist-ham10000.zip
# hmnist_28_28_RGB.csv	  skin_cancer_model.h5
# hmnist_8_8_L.csv	  test_skin.jpg
# hmnist_8_8_RGB.csv	  test_xray.jpg

# %%
# !kaggle datasets download -d arbethi/diabetic-retinopathy-level-detection
# Out:
# Dataset URL: https://www.kaggle.com/datasets/arbethi/diabetic-retinopathy-level-detection
# License(s): CC0-1.0
# ^C

# %%
# !pip install kagglehub

# %%
import kagglehub

path = kagglehub.dataset_download("arbethi/diabetic-retinopathy-level-detection")
print("Dataset downloaded to:", path)
# Out:
# ...
# 100%|██████████| 9.66G/9.66G [05:30<00:00, 31.4MB/s]
# Extracting files...
# Dataset downloaded to: /root/.cache/kagglehub/datasets/arbethi/diabetic-retinopathy-level-detection/versions/3

# %%
import os
os.listdir(path)
# Out:
# ['inception-diabetic.h5', 'preprocessed dataset']

# %%
import os

print(path)
print(os.listdir(path))
# Out:
# /root/.cache/kagglehub/datasets/arbethi/diabetic-retinopathy-level-detection/versions/3
# ['inception-diabetic.h5', 'preprocessed dataset']

# %%
for item in os.listdir(path):
    print(item, "->", os.listdir(os.path.join(path, item)) if os.path.isdir(os.path.join(path, item)) else "file")
# Out:
# inception-diabetic.h5 -> file
# preprocessed dataset -> ['preprocessed dataset']

# %%
deep_path = path + "/preprocessed dataset/preprocessed dataset"

import os
print(os.listdir(deep_path))
# Out:
# ['training', 'testing']

# %%
train_dir = deep_path + "/training"
test_dir  = deep_path + "/testing"

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=15,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode="categorical"
)
# Out:
# Found 3662 images belonging to 5 classes.

# %%
test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=(224,224),
    batch_size=32,
    class_mode="categorical",
    shuffle=False
)
# Out:
# Found 734 images belonging to 5 classes.

# %%
import tensorflow as tf

model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Conv2D(128, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(5, activation='softmax')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_data,
    epochs=10,
    validation_data=test_data
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 533s 5s/step - accuracy: 0.5525 - loss: 1.2981 - val_accuracy: 0.6975 - val_loss: 0.8850
# Epoch 2/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 510s 4s/step - accuracy: 0.6961 - loss: 0.9046 - val_accuracy: 0.7193 - val_loss: 0.8326
# Epoch 3/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 507s 4s/step - accuracy: 0.7082 - loss: 0.8342 - val_accuracy: 0.7207 - val_loss: 0.8180
# Epoch 4/10
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 507s 4s/step - accuracy: 0.7065 - loss: 0.8321 - val_accuracy: 0.7193 - val_loss: 0.8231
# Epoch 5/10
# ...

# %%
loss, accuracy = model.evaluate(test_data)
print("Test Accuracy:", accuracy)

# %%
model.save("diabetic_retinopathy_cnn.h5")

# %%
import cv2
import numpy as np

img = cv2.imread("test_image.jpg")
img = cv2.resize(img, (224,224))
img = img / 255.0
img = np.expand_dims(img, axis=0)

prediction = model.predict(img)
print("Predicted Class:", np.argmax(prediction))
